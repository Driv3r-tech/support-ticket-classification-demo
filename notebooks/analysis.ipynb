# %% [markdown]
# # Support Ticket Classification Demo
#
# Учебный notebook для первичного анализа датасета заявок поддержки.

# %%
import pandas as pd

df = pd.read_json('../data/clean_requests_100.json')
df.head()

# %%
df.info()

# %%
df['category'].value_counts()

# %%
df['priority'].value_counts()

# %%
df['status'].value_counts()

# %% [markdown]
# ## Базовая постановка ML-задачи
#
# ```python
# X = df['message']
# y = df['category']
# ```

# %%
X = df['message']
y = df['category']

X.head(), y.head()
